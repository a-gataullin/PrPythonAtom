# %%
import pandas as pd

# %%
data = pd.read_csv('ml5/train.csv', sep=';', index_col='id')
data.head()
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0   18393       2     168    62.0    110     80            1     1      0
# 1   20228       1     156    85.0    140     90            3     1      0
# 2   18857       1     165    64.0    130     70            3     1      0
# 3   17623       2     169    82.0    150    100            1     1      0
# 4   17474       1     156    56.0    100     60            1     1      0
#
#     alco  active  cardio
# id
# 0      0       1       0
# 1      0       1       1
# 2      0       0       1
# 3      0       1       1
# 4      0       0       0

# %%
data['age_year'] = data.age.apply(lambda x: x/365)

# %%
data.age_year
# Out:
# id
# 0        50.391781
# 1        55.419178
# 2        51.663014
# 3        48.282192
# 4        47.873973
# 8        60.038356
# 9        60.583562
# 12       61.873973
# 13       48.405479
# 14       54.339726
# 15       61.726027
# 16       51.547945
# 18       40.523288
# 21       54.271233
# 23       39.813699
# 24       45.978082
# 25       58.345205
# 27       45.882192
# 28       47.895890
# 29       59.602740
# 30       54.186301
# 31       58.665753
# 32       63.139726
# 33       64.043836
# 35       45.501370
# 36       39.597260
# 37       53.586301
# 38       49.547945
# 39       39.928767
# 40       57.690411
#            ...
# 99958    61.841096
# 99959    55.167123
# 99960    46.753425
# 99961    60.663014
# 99962    49.934247
# 99963    58.257534
# 99964    59.449315
# 99965    46.145205
# 99967    51.506849
# 99969    61.432877
# 99971    48.567123
# 99972    47.945205
# 99973    51.893151
# 99974    53.841096
# 99975    49.112329
# 99977    49.846575
# ...

# %%
data['age_year'].describe()
# Out:
# count    70000.000000
# mean        53.339358
# std          6.759594
# min         29.583562
# 25%         48.394521
# 50%         53.980822
# 75%         58.430137
# max         64.967123
# Name: age_year, dtype: float64

# %%
data.age_year.hist()

# %%
data[data.cardio==1]['age_year'].hist()

# %%
data[data.cardio==0]['age_year'].hist()

# %%
data[data.cardio==1]['gender'].value_counts()
# Out:
# 1    22616
# 2    12363
# Name: gender, dtype: int64

# %%
data[data.cardio==0]['gender'].value_counts()
# Out:
# 1    22914
# 2    12107
# Name: gender, dtype: int64

# %%
data[data['weight'] < 40]
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 5306   15400       1     120   30.00    110     70            1     1      0
# 8226   17663       1     151   37.00    120     80            1     1      0
# 14908  22007       1     162   38.00    100     70            1     1      0
# 15182  21669       1     153   37.00    150     80            3     3      0
# 16963  17512       1     157   39.00     90     70            1     1      0
# 21040  22663       1     143   34.00    100     70            1     1      0
# 23318  21872       1     165   35.00    100     70            1     1      0
# 24167  17272       2     170   31.00    150     90            2     2      0
# 26503  18140       1     160   30.00    120     80            1     1      0
# 27965  21334       1     152   38.00    110     80            1     1      0
# 31439  15359       1     146   32.00    100     70            1     1      0
# ...

# %%
data[data['height'] < 180]
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# 8      21914       1     151    67.0    120     80            2     2      0
# 9      22113       1     157    93.0    130     80            3     1      0
# 12     22584       2     178    95.0    130     90            3     3      0
# 13     17668       1     158    71.0    110     70            1     1      0
# 14     19834       1     164    68.0    110     60            1     1      0
# 15     22530       1     169    80.0    120     80            1     1      0
# ...

# %%
data['ap_hi'].describe()
# Out:
# count    70000.000000
# mean       128.817286
# std        154.011419
# min       -150.000000
# 25%        120.000000
# 50%        120.000000
# 75%        140.000000
# max      16020.000000
# Name: ap_hi, dtype: float64

# %%
data[data['ap_hi']<100]
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 71     17407       1     171    76.0     90     60            1     2      0
# 255    22527       1     165    67.0     90     60            1     1      0
# 288    18169       2     172    62.0     80     70            1     1      0
# 491    16021       1     156    60.0     90     60            1     1      0
# 543    19517       1     147    41.0     80     50            1     1      0
# 551    20943       2     158    52.0     90     60            1     1      1
# 632    16657       1     167    74.0     90     60            1     1      0
# 815    21281       1     168    78.0     14     90            2     1      0
# 900    16756       1     158    64.0     90     60            1     1      0
# 913    20457       2     169    68.0     70    110            1     1      0
# 1168   14659       1     148    42.0     90     60            1     1      0
# ...

# %%
pd.crosstab(data['cholesterol'], data['cardio'])
# Out:
# cardio           0      1
# cholesterol
# 1            29330  23055
# 2             3799   5750
# 3             1892   6174

# %%
data[data['cholesterol'] == 1].cardio.mean() 
#"и заполняем вот этими вот значениями"
# Out:
# 0.4401069008303904

# %%
pd.crosstab(data['alco'], data['cardio'])
# Out:
# cardio      0      1
# alco
# 0       33080  33156
# 1        1941   1823

# %%
pd.crosstab(data['smoke'], data['cardio'])

# %%
pd.crosstab(data['active'], data['cardio'])
